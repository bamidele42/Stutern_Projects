# %% [markdown]
# <a href="https://colab.research.google.com/github/bamidele42/Projects/blob/master/introduction_to_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Pandas_intro
# Out:
# /content/drive/MyDrive/Pandas_intro

# %%
# import libraries
import pandas as pd
import numpy as np

# %%
# read csv file
df = pd.read_csv("data.csv")

# check
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# inspecting the dataset
df.tail(10)
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 4590  2014-07-08 00:00:00  380680.555556       4.0       2.50         2620
# 4591  2014-07-08 00:00:00  396166.666667       3.0       1.75         1880
# 4592  2014-07-08 00:00:00  252980.000000       4.0       2.50         2530
# 4593  2014-07-08 00:00:00  289373.307692       3.0       2.50         2538
# 4594  2014-07-09 00:00:00  210614.285714       3.0       2.50         1610
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4590      8331     2.0           0     0          3        2620
# ...

# %%
# check number of row and column
df.shape
# Out:
# (4600, 18)

# %%
# selecting columns in a dataframe
price_and_bedrooms = df[["price", "bedrooms"]]

# %%
price_and_bedrooms.head()
# Out:
#        price  bedrooms
# 0   313000.0       3.0
# 1  2384000.0       5.0
# 2   342000.0       3.0
# 3   420000.0       3.0
# 4   550000.0       4.0

# %%
# selecting single rows
type(price_and_bedrooms.iloc[2])
# Out:
# pandas.core.series.Series

# %%
# selecting muiltiple rows
price_and_bedrooms.iloc[2:10] # the colon operator give it range
# Out:
#        price  bedrooms
# 0   313000.0       3.0
# 1  2384000.0       5.0
# 2   342000.0       3.0
# 3   420000.0       3.0
# 4   550000.0       4.0
# 5   490000.0       2.0
# 6   335000.0       2.0
# 7   482000.0       4.0
# 8   452500.0       3.0
# 9   640000.0       4.0

# %%
# select last set of rows
price_and_bedrooms.iloc[-5:]
# Out:
#               price  bedrooms
# 4595  308166.666667       3.0
# 4596  534333.333333       3.0
# 4597  416904.166667       3.0
# 4598  203400.000000       4.0
# 4599  220600.000000       3.0

# %%
# selecting rows with logic
# select rows where number of bedrooms is grater than 3
price_and_bedrooms[price_and_bedrooms["bedrooms"] > 3]]
# Out:
#   File "<ipython-input-24-cdcdc2e01174>", line 3
#     price_and_bedrooms[price_and_bedrooms["bedrooms"] > 3]]
#                                                           ^
# SyntaxError: invalid syntax

# %%
# select houses with more than three bedrooms and less than 2 bathrooms
df[(df["bedrooms"] > 3) & (df["bathrooms"] < 2)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-d3f4d0f4d19e> in <module>()
#       1 # select houses with more than three bedrooms and less than 2 bathrooms
# ----> 2 df[(df["bedrooms"] > 3) & (df["bathrooms"] < 2)]
#
# TypeError: list indices must be integers or slices, not str

# %%
# select houses with more than three bedrooms and less than 2 bathrooms
df[(df["bedrooms"] > 3) | (df["bathrooms"] < 2)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-deaba21df149> in <module>()
#       1 # select houses with more than three bedrooms and less than 2 bathrooms
# ----> 2 df[(df["bedrooms"] > 3) | (df["bathrooms"] < 2)]
#
# TypeError: list indices must be integers or slices, not str

# %%
# The isin operator
df[df["city"].isin(["seattle", "Renton", "Redmond"])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-75847bc01e60> in <module>()
#       1 # The isin operator
# ----> 2 df[df["city"].isin(["seattle", "Renton", "Redmond"])]
#
# TypeError: list indices must be integers or slices, not str

# %%
# create dummy data
df_2 = pd.DataFrame({"name": ["Mariam", "Amarachi", "stone", "peter", "binta"],
"Age": [29, 17, 19, 25, 26,]})

# check
df_2
# Out:
#        name  Age
# 0    Mariam   29
# 1  Amarachi   17
# 2     stone   19
# 3     peter   25
# 4     binta   26

# %%
df_2.head()
# Out:
#        name  Age
# 0    Mariam   29
# 1  Amarachi   17
# 2     stone   19
# 3     peter   25
# 4     binta   26
